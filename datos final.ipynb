# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Empezamos con el ingreso

# %%
ynr_95 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1995\\ynr_95.csv')
ynr_96 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1996\\ynr_96.csv')
ynr_97 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1997\\ynr_97.csv')
ynr_98 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1998\\ynr_98.csv')
ynr_99 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1999\\ynr_99.csv')
ynr_00 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2000\\ynr_00.csv')

ynr_02 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2002\\ynr_02.csv')
ynr_03 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2003\\ynr_03.csv')
ynr_04 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2004\\ynr_04.csv')
ynr_05 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2005\\ynr_05.csv')

ynr_07 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2007\\ynr_07.csv')
ynr_08 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2008\\ynr_08.csv')
ynr_09 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2009\\ynr_09.csv')
ynr_10 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2010\\ynr_10.csv')
ynr_11 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2011\\ynr_11.csv')
ynr_12 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2012\\ynr_12.csv')
ynr_13 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2013\\ynr_13.csv')
ynr_14 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2014\\ynr_14.csv')
ynr_15 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2015\\ynr_15.csv')

# %% [markdown]
# Creamos unas variables temporales 2001 y 2006

# %%
ynr_01 = ynr_00
ynr_06 = ynr_05

# %%
base_ynr = ynr_95.append(ynr_96).append(ynr_97).append(ynr_98).append(ynr_99).append(ynr_00).append(ynr_01).append(ynr_02).append(ynr_03).append(ynr_04).append(ynr_05).append(ynr_06).append(ynr_07).append(ynr_08).append(ynr_09).append(ynr_10).append(ynr_11).append(ynr_12).append(ynr_13).append(ynr_14).append(ynr_15)
base_ynr
# Out:
# C:\Users\PATRICIO\AppData\Local\Temp\ipykernel_3336\2247692409.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   base_ynr = ynr_95.append(ynr_96).append(ynr_97).append(ynr_98).append(ynr_99).append(ynr_00).append(ynr_01).append(ynr_02).append(ynr_03).append(ynr_04).append(ynr_05).append(ynr_06).append(ynr_07).append(ynr_08).append(ynr_09).append(ynr_10).append(ynr_11).append(ynr_12).append(ynr_13).append(ynr_14).append(ynr_15)
# C:\Users\PATRICIO\AppData\Local\Temp\ipykernel_3336\2247692409.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
data = pd.Series(np.arange(1,253))

# %%
base_ynr = base_ynr.set_index(data)

# %%
base_ynr = base_ynr.drop(['Unnamed: 0'], axis=1)

# %%
base_ynr
# Out:
#                26            29            31            33            35  \
# 1    1.894877e+06  1.982126e+06  1.379842e+06  3.045344e+06  1.544472e+06
# 2    1.003492e+06  3.001801e+06  1.272880e+06  2.911267e+06  1.216374e+06
# 3    1.440371e+06  3.210754e+06  7.009922e+05  3.139042e+06  6.533383e+05
# 4    9.394956e+05  3.943498e+06  8.468627e+05  2.964437e+06  5.131366e+05
# 5    1.692164e+06  3.203010e+06  2.535977e+05  4.011706e+06  4.868318e+05
# ..            ...           ...           ...           ...           ...
# 248  1.224754e+02  1.467117e+02  1.666864e+02  2.365872e+02  2.030255e+02
# 249  1.239988e+02  1.424430e+02  1.772626e+02  2.237981e+02  2.033322e+02
# 250  1.233863e+02  1.397561e+02  1.692269e+02  2.190668e+02  2.070863e+02
# 251  1.224505e+02  1.407396e+02  1.663772e+02  2.162665e+02  2.130471e+02
# 252  1.346890e+02  1.404789e+02  1.578019e+02  2.252294e+02  2.562080e+02
#
#                43   ano
# 1    1.599932e+06  1995
# 2    7.891247e+05  1995
# ...

# %%
base_ynr['mu'] = 0

# %%
for x in np.arange(1,253):
    base_ynr['mu'][x] = (base_ynr['26'][x]+base_ynr['29'][x]+base_ynr['31'][x]+base_ynr['33'][x]+base_ynr['35'][x]+base_ynr['43'][x])/6
base_ynr
# Out:
#                26            29            31            33            35  \
# 1    1.894877e+06  1.982126e+06  1.379842e+06  3.045344e+06  1.544472e+06
# 2    1.003492e+06  3.001801e+06  1.272880e+06  2.911267e+06  1.216374e+06
# 3    1.440371e+06  3.210754e+06  7.009922e+05  3.139042e+06  6.533383e+05
# 4    9.394956e+05  3.943498e+06  8.468627e+05  2.964437e+06  5.131366e+05
# 5    1.692164e+06  3.203010e+06  2.535977e+05  4.011706e+06  4.868318e+05
# ..            ...           ...           ...           ...           ...
# 248  1.224754e+02  1.467117e+02  1.666864e+02  2.365872e+02  2.030255e+02
# 249  1.239988e+02  1.424430e+02  1.772626e+02  2.237981e+02  2.033322e+02
# 250  1.233863e+02  1.397561e+02  1.692269e+02  2.190668e+02  2.070863e+02
# 251  1.224505e+02  1.407396e+02  1.663772e+02  2.162665e+02  2.130471e+02
# 252  1.346890e+02  1.404789e+02  1.578019e+02  2.252294e+02  2.562080e+02
#
#                43   ano            mu        ln
# ...

# %%
base_ynr['ln']=0

# %%
(base_ynr['mu'][254]+base_ynr['mu'][1])/base_ynr['mu'][1]
# Out:
# 1.890652636070287

# %%
for x in np.arange(1,252):
    base_ynr['ln'][x] = np.log(base_ynr['mu'][x])
base_ynr
# Out:
#                26            29            31            33            35  \
# 1    1.894877e+06  1.982126e+06  1.379842e+06  3.045344e+06  1.544472e+06
# 2    1.003492e+06  3.001801e+06  1.272880e+06  2.911267e+06  1.216374e+06
# 3    1.440371e+06  3.210754e+06  7.009922e+05  3.139042e+06  6.533383e+05
# 4    9.394956e+05  3.943498e+06  8.468627e+05  2.964437e+06  5.131366e+05
# 5    1.692164e+06  3.203010e+06  2.535977e+05  4.011706e+06  4.868318e+05
# ..            ...           ...           ...           ...           ...
# 248  1.224754e+02  1.467117e+02  1.666864e+02  2.365872e+02  2.030255e+02
# 249  1.239988e+02  1.424430e+02  1.772626e+02  2.237981e+02  2.033322e+02
# 250  1.233863e+02  1.397561e+02  1.692269e+02  2.190668e+02  2.070863e+02
# 251  1.224505e+02  1.407396e+02  1.663772e+02  2.162665e+02  2.130471e+02
# 252  1.346890e+02  1.404789e+02  1.578019e+02  2.252294e+02  2.562080e+02
#
#                43   ano            mu         ln
# ...

# %%
base_ynr['ln'].loc[base_ynr['ln']!=0].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Empezamos con los índices de Atkinson 25

# %%
a25_95 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1995\\a25_95.csv')
a25_96 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1996\\a25_96.csv')
a25_97 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1997\\a25_97.csv')
a25_98 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1998\\a25_98.csv')
a25_99 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\1999\\a25_99.csv')
a25_00 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2000\\a25_00.csv')

a25_02 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2002\\a25_02.csv')
a25_03 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2003\\a25_03.csv')
a25_04 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2004\\a25_04.csv')
a25_05 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2005\\a25_05.csv')

a25_07 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2007\\a25_07.csv')
a25_08 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2008\\a25_08.csv')
a25_09 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2009\\a25_09.csv')
a25_10 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2010\\a25_10.csv')
a25_11 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2011\\a25_11.csv')
a25_12 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2012\\a25_12.csv')
a25_13 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2013\\a25_13.csv')
a25_14 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2014\\a25_14.csv')
a25_15 = pd.read_csv('C:\\edu\\Investigación\\Replicación\\datos\\final\\2015\\a25_15.csv')

# %% [markdown]
# Creamos unas variables temporales 2001 y 2006

# %%
a25_01 = a25_00
a25_06 = a25_05

# %%
base_a25 = a25_95.append(a25_96).append(a25_97).append(a25_98).append(a25_99).append(a25_00).append(a25_01).append(a25_02).append(a25_03).append(a25_04).append(a25_05).append(a25_06).append(a25_07).append(a25_08).append(a25_09).append(a25_10).append(a25_11).append(a25_12).append(a25_13).append(a25_14).append(a25_15)
base_a25
# Out:
# C:\Users\PATRICIO\AppData\Local\Temp\ipykernel_3336\2409197400.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   base_a25 = a25_95.append(a25_96).append(a25_97).append(a25_98).append(a25_99).append(a25_00).append(a25_01).append(a25_02).append(a25_03).append(a25_04).append(a25_05).append(a25_06).append(a25_07).append(a25_08).append(a25_09).append(a25_10).append(a25_11).append(a25_12).append(a25_13).append(a25_14).append(a25_15)
# C:\Users\PATRICIO\AppData\Local\Temp\ipykernel_3336\2409197400.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
data = pd.Series(np.arange(1,252))
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 247    248
# 248    249
# 249    250
# 250    251
# 251    252
# Length: 252, dtype: int32

# %%
base_a25 = base_a25.set_index(data)

# %%
base_a25
# Out:
#            26        29        31        33        35        43   ano
# 1    0.854036  0.837557  0.854775  0.828591  0.876262  0.869050  1995
# 2    0.863317  0.821562  0.865014  0.822520  0.878904  0.880802  1995
# 3    0.854204  0.816464  0.869718  0.841644  0.904430  0.866086  1995
# 4    0.867725  0.809542  0.884272  0.835924  0.908013  0.867623  1995
# 5    0.840330  0.797697  0.900296  0.813150  0.903270  0.886057  1995
# ..        ...       ...       ...       ...       ...       ...   ...
# 248  0.115078  0.141934  0.127710  0.167568  0.117248  0.123303  2015
# 249  0.118487  0.123546  0.137613  0.151370  0.118288  0.126706  2015
# 250  0.119564  0.125241  0.132443  0.144880  0.117935  0.128588  2015
# 251  0.119543  0.128592  0.129623  0.139970  0.124939  0.123266  2015
# 252  0.120869  0.124189  0.118683  0.147911  0.125936  0.129820  2015
#
# [252 rows x 7 columns]

# %%
base_a25['26'].loc[base_a25['26']<0.5].plot()
# Out:
# <AxesSubplot: >
